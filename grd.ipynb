# %%
# gpu guy run this code and make sure weights are saved in /weights folder, then push to repo

# %%
import gymnasium as gym
import torch
import time
import numpy as np
import torch.nn.functional as F
from modules import GenerativeModel, ReplayBuffer, DiscreteSACAgent, EpisodicRewardWrapper

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LR_POLICY = 3e-4          # Learning rate for actor and critic
LR_GENERATIVE = 3e-4      # Learning rate for generative model
GAMMA = 0.99              # Discount factor
REPLAY_BUFFER_SIZE = 50000 # Size of the replay buffer
BATCH_SIZE = 256          # Batch size for training
TAU = 0.005               # Soft update coefficient for target networks
ALPHA = 0.2               # SAC temperature parameter (entropy regularization)
HIDDEN_DIM = 256          # Hidden dimension for neural networks
MAX_EPISODES = 500      # Total number of episodes to run
MAX_STEPS_PER_EPISODE = 500 # Max steps per episode for CartPole-v1
START_TRAINING_EPISODES = 10 # Number of episodes to collect data before training starts

# Hyperparameters for the GRD generative model loss (L_reg)
# These control the sparsity of the learned causal graph. Increased to encourage sparsity.
LAMBDA_S_R = 5e-4  # state -> reward
LAMBDA_A_R = 1e-5  # action -> reward
LAMBDA_S_S = 5e-5  # state -> state
LAMBDA_A_S = 1e-8  # action -> state

# %%
env = gym.make("CartPole-v1")
env = EpisodicRewardWrapper(env)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

compact_state_dim = state_dim 

replay_buffer = ReplayBuffer(REPLAY_BUFFER_SIZE)
generative_model = GenerativeModel(state_dim, action_dim, HIDDEN_DIM, DEVICE, LR_GENERATIVE, GAMMA, LAMBDA_S_S, LAMBDA_S_R, LAMBDA_A_S, LAMBDA_A_R)
sac_agent = DiscreteSACAgent(state_dim, action_dim, compact_state_dim, HIDDEN_DIM, DEVICE, LR_POLICY, TAU, GAMMA, ALPHA)

# %%
print(f"Using device: {DEVICE}")
print(f"State dim: {state_dim}, Action dim: {action_dim}")

start_time = time.time()
all_episode_steps = []

rewards = []

for i_episode in range(1, MAX_EPISODES + 1):
    state, _ = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=DEVICE).unsqueeze(0)
    
    episode_reward = 0
    episode_states = []
    episode_actions = []
    
    for t in range(MAX_STEPS_PER_EPISODE):
        with torch.no_grad():
            C_s_s, _, C_s_r, _ = generative_model.causal_module.get_causal_masks(training=False)
            compact_mask = generative_model.causal_module.get_compact_representation_mask(C_s_s, C_s_r)
            compact_state = state * compact_mask

        action = sac_agent.select_action(compact_state)
        
        next_state_np, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        
        # The episodic reward is only non-zero at the end
        # The immediate reward for the replay buffer is this episodic reward if done, else 0
        replay_reward = reward if done else 0.0
        episode_reward += reward 
        
        next_state = torch.tensor(next_state_np, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        
        # Push the transition with the immediate (mostly zero) reward
        replay_buffer.push(state, action, next_state, replay_reward, done)
        episode_states.append(state)
        episode_actions.append(action)
        
        state = next_state

        if len(replay_buffer) > BATCH_SIZE and i_episode > START_TRAINING_EPISODES:
            # Update Generative Model
            generative_model.optimizer.zero_grad()
            transitions = replay_buffer.sample(BATCH_SIZE)
            trajectories = replay_buffer.sample_trajectories(4)
            gen_loss, l_rew, l_dyn, l_reg = generative_model.calculate_loss(trajectories, transitions)
            if torch.is_tensor(gen_loss):
                gen_loss.backward()
                generative_model.optimizer.step()

            # Update Policy Model
            actor_loss, critic_loss = sac_agent.update(transitions, generative_model)

        if done:
            break
    
    all_episode_steps.append(t + 1)

    # After episode ends, store the full trajectory with the final episodic return
    if episode_reward > 0:
        ep_states_tensor = torch.cat(episode_states, dim=0)
        ep_actions_tensor = torch.tensor(episode_actions, device=DEVICE, dtype=torch.long)
        ep_return_tensor = torch.tensor([episode_reward], dtype=torch.float32, device=DEVICE)
        replay_buffer.push_trajectory(ep_states_tensor, ep_actions_tensor, ep_return_tensor)

    if i_episode % 1 == 0:
        avg_steps = np.mean(all_episode_steps[-100:]) # Average over last 100 episodes
        elapsed_time = time.time() - start_time
        print(f"Epi {i_episode}/{MAX_EPISODES} | Avg Steps (last 100): {avg_steps:.2f} | Steps: {t+1} | Time: {elapsed_time:.2f}s")
        print(f"Reward: {episode_reward}")
        rewards.append(episode_reward)
        if len(replay_buffer) > BATCH_SIZE and i_episode > START_TRAINING_EPISODES and torch.is_tensor(gen_loss):
            print(f"  Losses -> Gen: {gen_loss.item():.4f} (Rew: {l_rew.item():.4f}, Dyn: {l_dyn.item():.4f}, Reg: {l_reg.item():.4f})")
            print(f"  Policy -> Actor: {actor_loss:.4f}, Critic: {critic_loss:.4f}")

        with torch.no_grad():
            C_s_s, _, C_s_r, C_a_r = generative_model.causal_module.get_causal_masks(training=False)
            compact_mask = generative_model.causal_module.get_compact_representation_mask(C_s_s, C_s_r)
            s_r_probs = F.softmax(generative_model.causal_module.s_to_r_logits, dim=-1)[:, 1].cpu().numpy()
            a_r_probs = F.softmax(generative_model.causal_module.a_to_r_logits, dim=-1)[:, 1].cpu().numpy()
            print(f"  Causal Probs (S->R): {[f'{p:.2f}' for p in s_r_probs]}")
            print(f"  Compact Mask: {compact_mask.cpu().numpy()}")

env.close()
# Out:
# Using device: cuda
# State dim: 4, Action dim: 2
# Epi 1/500 | Avg Steps (last 100): 19.00 | Steps: 19 | Time: 0.68s
# Reward: 19.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 2/500 | Avg Steps (last 100): 24.00 | Steps: 29 | Time: 0.77s
# Reward: 29.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 3/500 | Avg Steps (last 100): 31.67 | Steps: 47 | Time: 0.89s
# Reward: 47.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 4/500 | Avg Steps (last 100): 27.00 | Steps: 13 | Time: 0.92s
# Reward: 13.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 5/500 | Avg Steps (last 100): 31.00 | Steps: 47 | Time: 1.04s
# Reward: 47.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 6/500 | Avg Steps (last 100): 27.33 | Steps: 9 | Time: 1.07s
# Reward: 9.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 7/500 | Avg Steps (last 100): 26.71 | Steps: 23 | Time: 1.12s
# Reward: 23.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [0. 0. 0. 0.]
# Epi 8/500 | Avg Steps (last 100): 25.00 | Steps: 13 | Time: 1.16s
# Reward: 13.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 9/500 | Avg Steps (last 100): 24.22 | Steps: 18 | Time: 1.21s
# Reward: 18.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 10/500 | Avg Steps (last 100): 23.00 | Steps: 12 | Time: 1.25s
# Reward: 12.0
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [0. 0. 0. 1.]
# e:\S3\RL\Research Project\Generative-Reward-Decomposition-RL\modules\GenerativeModel.py:51: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   rew_losses.append(F.mse_loss(predicted_return, total_return))
# Epi 11/500 | Avg Steps (last 100): 26.36 | Steps: 60 | Time: 2.41s
# Reward: 60.0
#   Losses -> Gen: 9.6820 (Rew: 9.6589, Dyn: 0.0212, Reg: 0.0019)
#   Policy -> Actor: -1.5698, Critic: 0.0698
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [0. 0. 0. 0.]
# Epi 12/500 | Avg Steps (last 100): 24.92 | Steps: 9 | Time: 2.63s
# Reward: 9.0
#   Losses -> Gen: 45.3405 (Rew: 45.3221, Dyn: 0.0164, Reg: 0.0019)
#   Policy -> Actor: -1.7394, Critic: 0.1646
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 13/500 | Avg Steps (last 100): 23.69 | Steps: 9 | Time: 2.86s
# Reward: 9.0
#   Losses -> Gen: 16.7715 (Rew: 16.7446, Dyn: 0.0249, Reg: 0.0019)
#   Policy -> Actor: -1.6504, Critic: 0.1544
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 14/500 | Avg Steps (last 100): 24.00 | Steps: 28 | Time: 3.54s
# Reward: 28.0
#   Losses -> Gen: 11.5028 (Rew: 11.4880, Dyn: 0.0129, Reg: 0.0019)
#   Policy -> Actor: -1.8627, Critic: 0.0716
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 15/500 | Avg Steps (last 100): 23.13 | Steps: 11 | Time: 3.81s
# Reward: 11.0
#   Losses -> Gen: 14.4885 (Rew: 14.4771, Dyn: 0.0095, Reg: 0.0019)
#   Policy -> Actor: -1.8974, Critic: 0.0431
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 16/500 | Avg Steps (last 100): 22.19 | Steps: 8 | Time: 4.00s
# Reward: 8.0
#   Losses -> Gen: 5.0991 (Rew: 5.0820, Dyn: 0.0152, Reg: 0.0019)
#   Policy -> Actor: -1.7858, Critic: 0.0878
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 17/500 | Avg Steps (last 100): 21.71 | Steps: 14 | Time: 4.34s
# Reward: 14.0
#   Losses -> Gen: 14.0957 (Rew: 14.0831, Dyn: 0.0107, Reg: 0.0019)
#   Policy -> Actor: -2.0021, Critic: 0.0662
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 18/500 | Avg Steps (last 100): 21.28 | Steps: 14 | Time: 4.68s
# Reward: 14.0
#   Losses -> Gen: 4.3871 (Rew: 4.3739, Dyn: 0.0112, Reg: 0.0019)
#   Policy -> Actor: -1.8935, Critic: 0.0293
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [0. 0. 0. 0.]
# Epi 19/500 | Avg Steps (last 100): 20.84 | Steps: 13 | Time: 4.99s
# Reward: 13.0
#   Losses -> Gen: 4.5568 (Rew: 4.5413, Dyn: 0.0135, Reg: 0.0019)
#   Policy -> Actor: -2.1064, Critic: 0.0872
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 20/500 | Avg Steps (last 100): 20.65 | Steps: 17 | Time: 5.42s
# Reward: 17.0
#   Losses -> Gen: 4.0206 (Rew: 4.0029, Dyn: 0.0157, Reg: 0.0019)
#   Policy -> Actor: -2.1246, Critic: 0.0883
#   Causal Probs (S->R): ['0.40', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 21/500 | Avg Steps (last 100): 20.24 | Steps: 12 | Time: 5.71s
# Reward: 12.0
#   Losses -> Gen: 5.6180 (Rew: 5.6100, Dyn: 0.0061, Reg: 0.0019)
#   Policy -> Actor: -2.2491, Critic: 0.1022
#   Causal Probs (S->R): ['0.41', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 22/500 | Avg Steps (last 100): 19.82 | Steps: 11 | Time: 5.97s
# Reward: 11.0
#   Losses -> Gen: 2.0838 (Rew: 2.0736, Dyn: 0.0082, Reg: 0.0019)
#   Policy -> Actor: -2.2423, Critic: 0.1090
#   Causal Probs (S->R): ['0.41', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 23/500 | Avg Steps (last 100): 19.61 | Steps: 15 | Time: 6.33s
# Reward: 15.0
#   Losses -> Gen: 3.8651 (Rew: 3.8445, Dyn: 0.0187, Reg: 0.0019)
#   Policy -> Actor: -2.3550, Critic: 0.1192
#   Causal Probs (S->R): ['0.41', '0.75', '0.17', '0.42']
#   Compact Mask: [0. 1. 1. 1.]
# Epi 24/500 | Avg Steps (last 100): 20.25 | Steps: 35 | Time: 7.21s
# Reward: 35.0
#   Losses -> Gen: 3.7856 (Rew: 3.7780, Dyn: 0.0056, Reg: 0.0019)
#   Policy -> Actor: -2.5174, Critic: 0.0997
#   Causal Probs (S->R): ['0.41', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 25/500 | Avg Steps (last 100): 20.04 | Steps: 15 | Time: 7.58s
# Reward: 15.0
#   Losses -> Gen: 0.0471 (Rew: 0.0329, Dyn: 0.0123, Reg: 0.0019)
#   Policy -> Actor: -2.5602, Critic: 0.1753
#   Causal Probs (S->R): ['0.41', '0.75', '0.17', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 26/500 | Avg Steps (last 100): 20.31 | Steps: 27 | Time: 8.26s
# Reward: 27.0
#   Losses -> Gen: 2.7492 (Rew: 2.7425, Dyn: 0.0048, Reg: 0.0019)
#   Policy -> Actor: -2.7215, Critic: 0.1254
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 27/500 | Avg Steps (last 100): 20.22 | Steps: 18 | Time: 8.72s
# Reward: 18.0
#   Losses -> Gen: 3.7076 (Rew: 3.6930, Dyn: 0.0126, Reg: 0.0020)
#   Policy -> Actor: -2.6612, Critic: 0.1871
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.41']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 28/500 | Avg Steps (last 100): 20.18 | Steps: 19 | Time: 9.20s
# Reward: 19.0
#   Losses -> Gen: 1.6670 (Rew: 1.6513, Dyn: 0.0138, Reg: 0.0020)
#   Policy -> Actor: -2.8349, Critic: 0.1344
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.41']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 29/500 | Avg Steps (last 100): 20.00 | Steps: 15 | Time: 9.58s
# Reward: 15.0
#   Losses -> Gen: 1.3440 (Rew: 1.3376, Dyn: 0.0044, Reg: 0.0020)
#   Policy -> Actor: -2.9129, Critic: 0.1332
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.41']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 30/500 | Avg Steps (last 100): 20.83 | Steps: 45 | Time: 10.70s
# Reward: 45.0
#   Losses -> Gen: 1.7061 (Rew: 1.6900, Dyn: 0.0141, Reg: 0.0020)
#   Policy -> Actor: -3.2166, Critic: 0.2250
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.41']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 31/500 | Avg Steps (last 100): 20.94 | Steps: 24 | Time: 11.29s
# Reward: 24.0
#   Losses -> Gen: 0.7964 (Rew: 0.7847, Dyn: 0.0097, Reg: 0.0020)
#   Policy -> Actor: -3.2780, Critic: 0.2026
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.41']
#   Compact Mask: [0. 0. 0. 1.]
# Epi 32/500 | Avg Steps (last 100): 20.81 | Steps: 17 | Time: 11.70s
# Reward: 17.0
#   Losses -> Gen: 0.7031 (Rew: 0.6912, Dyn: 0.0100, Reg: 0.0020)
#   Policy -> Actor: -3.3299, Critic: 0.3150
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.41']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 33/500 | Avg Steps (last 100): 20.76 | Steps: 19 | Time: 12.17s
# Reward: 19.0
#   Losses -> Gen: 1.7906 (Rew: 1.7781, Dyn: 0.0106, Reg: 0.0020)
#   Policy -> Actor: -3.4552, Critic: 0.1992
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 34/500 | Avg Steps (last 100): 20.76 | Steps: 21 | Time: 12.68s
# Reward: 21.0
#   Losses -> Gen: 5.8660 (Rew: 5.8505, Dyn: 0.0135, Reg: 0.0020)
#   Policy -> Actor: -3.5234, Critic: 0.2289
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 35/500 | Avg Steps (last 100): 20.51 | Steps: 12 | Time: 12.97s
# Reward: 12.0
#   Losses -> Gen: 7.5057 (Rew: 7.5003, Dyn: 0.0034, Reg: 0.0020)
#   Policy -> Actor: -3.7629, Critic: 0.7033
#   Causal Probs (S->R): ['0.41', '0.75', '0.18', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 36/500 | Avg Steps (last 100): 21.14 | Steps: 43 | Time: 14.00s
# Reward: 43.0
#   Losses -> Gen: 1.3563 (Rew: 1.3465, Dyn: 0.0078, Reg: 0.0020)
#   Policy -> Actor: -3.8450, Critic: 0.3841
#   Causal Probs (S->R): ['0.42', '0.75', '0.18', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 37/500 | Avg Steps (last 100): 21.05 | Steps: 18 | Time: 14.44s
# Reward: 18.0
#   Losses -> Gen: 1.2561 (Rew: 1.2461, Dyn: 0.0080, Reg: 0.0020)
#   Policy -> Actor: -3.8316, Critic: 0.3774
#   Causal Probs (S->R): ['0.42', '0.75', '0.19', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 38/500 | Avg Steps (last 100): 21.00 | Steps: 19 | Time: 14.90s
# Reward: 19.0
#   Losses -> Gen: 1.4498 (Rew: 1.4141, Dyn: 0.0336, Reg: 0.0020)
#   Policy -> Actor: -4.0276, Critic: 0.3773
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 39/500 | Avg Steps (last 100): 20.90 | Steps: 17 | Time: 15.31s
# Reward: 17.0
#   Losses -> Gen: 2.7947 (Rew: 2.7889, Dyn: 0.0038, Reg: 0.0020)
#   Policy -> Actor: -3.9432, Critic: 0.3858
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [1. 0. 1. 0.]
# Epi 40/500 | Avg Steps (last 100): 20.82 | Steps: 18 | Time: 15.74s
# Reward: 18.0
#   Losses -> Gen: 5.6333 (Rew: 5.6247, Dyn: 0.0066, Reg: 0.0020)
#   Policy -> Actor: -4.1879, Critic: 0.3813
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [0. 1. 1. 1.]
# Epi 41/500 | Avg Steps (last 100): 20.78 | Steps: 19 | Time: 16.21s
# Reward: 19.0
#   Losses -> Gen: 0.1891 (Rew: 0.1786, Dyn: 0.0085, Reg: 0.0020)
#   Policy -> Actor: -4.1757, Critic: 0.4632
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [0. 1. 1. 1.]
# Epi 42/500 | Avg Steps (last 100): 20.90 | Steps: 26 | Time: 16.83s
# Reward: 26.0
#   Losses -> Gen: 3.8743 (Rew: 3.8701, Dyn: 0.0022, Reg: 0.0020)
#   Policy -> Actor: -4.6116, Critic: 1.1305
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 43/500 | Avg Steps (last 100): 20.72 | Steps: 13 | Time: 17.15s
# Reward: 13.0
#   Losses -> Gen: 1.4917 (Rew: 1.4874, Dyn: 0.0023, Reg: 0.0020)
#   Policy -> Actor: -4.4550, Critic: 0.5949
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 44/500 | Avg Steps (last 100): 20.66 | Steps: 18 | Time: 17.59s
# Reward: 18.0
#   Losses -> Gen: 10.6830 (Rew: 10.6790, Dyn: 0.0020, Reg: 0.0020)
#   Policy -> Actor: -4.5561, Critic: 0.5777
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 45/500 | Avg Steps (last 100): 20.62 | Steps: 19 | Time: 18.04s
# Reward: 19.0
#   Losses -> Gen: 0.0283 (Rew: 0.0202, Dyn: 0.0061, Reg: 0.0020)
#   Policy -> Actor: -4.8889, Critic: 1.4832
#   Causal Probs (S->R): ['0.42', '0.76', '0.19', '0.42']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 46/500 | Avg Steps (last 100): 20.59 | Steps: 19 | Time: 18.50s
# Reward: 19.0
#   Losses -> Gen: 6.4388 (Rew: 6.4325, Dyn: 0.0042, Reg: 0.0020)
#   Policy -> Actor: -4.7903, Critic: 0.4847
#   Causal Probs (S->R): ['0.42', '0.76', '0.20', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 47/500 | Avg Steps (last 100): 20.45 | Steps: 14 | Time: 18.84s
# Reward: 14.0
#   Losses -> Gen: 0.1202 (Rew: 0.1067, Dyn: 0.0115, Reg: 0.0020)
#   Policy -> Actor: -4.9067, Critic: 0.8968
#   Causal Probs (S->R): ['0.42', '0.76', '0.20', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 48/500 | Avg Steps (last 100): 20.40 | Steps: 18 | Time: 19.28s
# Reward: 18.0
#   Losses -> Gen: 0.3864 (Rew: 0.3649, Dyn: 0.0194, Reg: 0.0020)
#   Policy -> Actor: -5.0746, Critic: 1.8799
#   Causal Probs (S->R): ['0.42', '0.76', '0.20', '0.42']
#   Compact Mask: [0. 1. 1. 1.]
# Epi 49/500 | Avg Steps (last 100): 20.59 | Steps: 30 | Time: 19.99s
# Reward: 30.0
#   Losses -> Gen: 0.3483 (Rew: 0.3421, Dyn: 0.0042, Reg: 0.0020)
#   Policy -> Actor: -5.0171, Critic: 0.5734
#   Causal Probs (S->R): ['0.43', '0.76', '0.20', '0.42']
#   Compact Mask: [1. 0. 1. 1.]
# Epi 50/500 | Avg Steps (last 100): 20.50 | Steps: 16 | Time: 20.39s
# Reward: 16.0
#   Losses -> Gen: 2.5059 (Rew: 2.4998, Dyn: 0.0041, Reg: 0.0020)
#   Policy -> Actor: -5.2206, Critic: 0.5454
#   Causal Probs (S->R): ['0.43', '0.76', '0.20', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 51/500 | Avg Steps (last 100): 20.69 | Steps: 30 | Time: 21.09s
# Reward: 30.0
#   Losses -> Gen: 2.5202 (Rew: 2.5124, Dyn: 0.0058, Reg: 0.0020)
#   Policy -> Actor: -5.3925, Critic: 1.4873
#   Causal Probs (S->R): ['0.43', '0.76', '0.20', '0.42']
#   Compact Mask: [0. 0. 0. 0.]
# Epi 52/500 | Avg Steps (last 100): 20.94 | Steps: 34 | Time: 21.90s
# Reward: 34.0
#   Losses -> Gen: 0.9069 (Rew: 0.9003, Dyn: 0.0046, Reg: 0.0020)
#   Policy -> Actor: -5.5166, Critic: 0.5053
#   Causal Probs (S->R): ['0.43', '0.76', '0.20', '0.42']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 53/500 | Avg Steps (last 100): 20.98 | Steps: 23 | Time: 22.45s
# Reward: 23.0
#   Losses -> Gen: 2.5709 (Rew: 2.5660, Dyn: 0.0028, Reg: 0.0020)
#   Policy -> Actor: -5.6902, Critic: 0.6854
#   Causal Probs (S->R): ['0.43', '0.76', '0.20', '0.43']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 54/500 | Avg Steps (last 100): 20.98 | Steps: 21 | Time: 22.94s
# Reward: 21.0
#   Losses -> Gen: 0.4277 (Rew: 0.4202, Dyn: 0.0054, Reg: 0.0020)
#   Policy -> Actor: -5.5713, Critic: 0.9785
#   Causal Probs (S->R): ['0.43', '0.76', '0.20', '0.43']
#   Compact Mask: [0. 1. 0. 0.]
# Epi 55/500 | Avg Steps (last 100): 20.89 | Steps: 16 | Time: 23.32s
# Reward: 16.0
#   Losses -> Gen: 3.1282 (Rew: 3.1189, Dyn: 0.0073, Reg: 0.0020)
#   Policy -> Actor: -5.6375, Critic: 0.9483
#   Causal Probs (S->R): ['0.43', '0.76', '0.21', '0.43']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 56/500 | Avg Steps (last 100): 21.73 | Steps: 68 | Time: 24.92s
# Reward: 68.0
#   Losses -> Gen: 9.1527 (Rew: 9.1486, Dyn: 0.0021, Reg: 0.0021)
#   Policy -> Actor: -6.0643, Critic: 0.8528
#   Causal Probs (S->R): ['0.44', '0.76', '0.21', '0.43']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 57/500 | Avg Steps (last 100): 22.86 | Steps: 86 | Time: 26.95s
# Reward: 86.0
#   Losses -> Gen: 6.4529 (Rew: 6.4416, Dyn: 0.0093, Reg: 0.0021)
#   Policy -> Actor: -6.4710, Critic: 1.0684
#   Causal Probs (S->R): ['0.44', '0.76', '0.21', '0.43']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 58/500 | Avg Steps (last 100): 23.22 | Steps: 44 | Time: 27.99s
# Reward: 44.0
#   Losses -> Gen: 0.8744 (Rew: 0.8698, Dyn: 0.0025, Reg: 0.0021)
#   Policy -> Actor: -6.4638, Critic: 1.3492
#   Causal Probs (S->R): ['0.44', '0.76', '0.21', '0.43']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 59/500 | Avg Steps (last 100): 24.37 | Steps: 91 | Time: 30.14s
# Reward: 91.0
#   Losses -> Gen: 3.5117 (Rew: 3.5072, Dyn: 0.0024, Reg: 0.0021)
#   Policy -> Actor: -7.5082, Critic: 1.8411
#   Causal Probs (S->R): ['0.44', '0.76', '0.21', '0.44']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 60/500 | Avg Steps (last 100): 24.98 | Steps: 61 | Time: 31.58s
# Reward: 61.0
#   Losses -> Gen: 8.3805 (Rew: 8.3747, Dyn: 0.0036, Reg: 0.0021)
#   Policy -> Actor: -7.6421, Critic: 0.7669
#   Causal Probs (S->R): ['0.44', '0.76', '0.21', '0.44']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 61/500 | Avg Steps (last 100): 25.80 | Steps: 75 | Time: 33.45s
# Reward: 75.0
#   Losses -> Gen: 3.0645 (Rew: 3.0586, Dyn: 0.0038, Reg: 0.0021)
#   Policy -> Actor: -7.9733, Critic: 1.9001
#   Causal Probs (S->R): ['0.45', '0.77', '0.21', '0.46']
#   Compact Mask: [1. 0. 0. 0.]
# Epi 62/500 | Avg Steps (last 100): 27.32 | Steps: 120 | Time: 36.28s
# Reward: 120.0
#   Losses -> Gen: 4.3071 (Rew: 4.3026, Dyn: 0.0023, Reg: 0.0021)
#   Policy -> Actor: -8.4063, Critic: 1.5022
#   Causal Probs (S->R): ['0.45', '0.78', '0.21', '0.47']
#   Compact Mask: [0. 0. 0. 0.]
# Epi 63/500 | Avg Steps (last 100): 27.98 | Steps: 69 | Time: 37.95s
# Reward: 69.0
#   Losses -> Gen: 44.3840 (Rew: 44.3743, Dyn: 0.0074, Reg: 0.0022)
#   Policy -> Actor: -9.3956, Critic: 3.5352
#   Causal Probs (S->R): ['0.46', '0.78', '0.22', '0.48']
#   Compact Mask: [0. 1. 0. 0.]
# Epi 64/500 | Avg Steps (last 100): 28.83 | Steps: 82 | Time: 39.88s
# Reward: 82.0
#   Losses -> Gen: 35.5765 (Rew: 35.5701, Dyn: 0.0042, Reg: 0.0022)
#   Policy -> Actor: -9.4279, Critic: 1.4467
#   Causal Probs (S->R): ['0.47', '0.78', '0.22', '0.50']
#   Compact Mask: [1. 1. 1. 0.]
# Epi 65/500 | Avg Steps (last 100): 30.11 | Steps: 112 | Time: 42.63s
# Reward: 112.0
#   Losses -> Gen: 2.9958 (Rew: 2.9862, Dyn: 0.0073, Reg: 0.0023)
#   Policy -> Actor: -9.9832, Critic: 1.5288
#   Causal Probs (S->R): ['0.47', '0.78', '0.23', '0.51']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 66/500 | Avg Steps (last 100): 32.55 | Steps: 191 | Time: 47.20s
# Reward: 191.0
#   Losses -> Gen: 7.8451 (Rew: 7.8350, Dyn: 0.0078, Reg: 0.0023)
#   Policy -> Actor: -11.6959, Critic: 0.8438
#   Causal Probs (S->R): ['0.49', '0.80', '0.24', '0.53']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 67/500 | Avg Steps (last 100): 33.76 | Steps: 114 | Time: 49.92s
# Reward: 114.0
#   Losses -> Gen: 35.2680 (Rew: 35.2607, Dyn: 0.0049, Reg: 0.0024)
#   Policy -> Actor: -12.4166, Critic: 4.3967
#   Causal Probs (S->R): ['0.49', '0.80', '0.25', '0.55']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 68/500 | Avg Steps (last 100): 34.57 | Steps: 89 | Time: 52.02s
# Reward: 89.0
#   Losses -> Gen: 43.4785 (Rew: 43.4602, Dyn: 0.0159, Reg: 0.0024)
#   Policy -> Actor: -12.6107, Critic: 1.7642
#   Causal Probs (S->R): ['0.49', '0.80', '0.25', '0.56']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 69/500 | Avg Steps (last 100): 35.68 | Steps: 111 | Time: 54.62s
# Reward: 111.0
#   Losses -> Gen: 2.9839 (Rew: 2.9758, Dyn: 0.0057, Reg: 0.0024)
#   Policy -> Actor: -13.5653, Critic: 0.5841
#   Causal Probs (S->R): ['0.49', '0.80', '0.26', '0.57']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 70/500 | Avg Steps (last 100): 37.63 | Steps: 172 | Time: 58.70s
# Reward: 172.0
#   Losses -> Gen: 33.0322 (Rew: 33.0265, Dyn: 0.0032, Reg: 0.0025)
#   Policy -> Actor: -14.8220, Critic: 1.5603
#   Causal Probs (S->R): ['0.49', '0.81', '0.27', '0.59']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 71/500 | Avg Steps (last 100): 39.52 | Steps: 172 | Time: 62.81s
# Reward: 172.0
#   Losses -> Gen: 86.3575 (Rew: 86.3522, Dyn: 0.0028, Reg: 0.0025)
#   Policy -> Actor: -15.5406, Critic: 2.0409
#   Causal Probs (S->R): ['0.49', '0.82', '0.29', '0.61']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 72/500 | Avg Steps (last 100): 41.93 | Steps: 213 | Time: 67.84s
# Reward: 213.0
#   Losses -> Gen: 838.1677 (Rew: 838.1565, Dyn: 0.0085, Reg: 0.0026)
#   Policy -> Actor: -16.9831, Critic: 3.0721
#   Causal Probs (S->R): ['0.49', '0.82', '0.31', '0.62']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 73/500 | Avg Steps (last 100): 43.42 | Steps: 151 | Time: 71.43s
# Reward: 151.0
#   Losses -> Gen: 4.7379 (Rew: 4.7218, Dyn: 0.0134, Reg: 0.0026)
#   Policy -> Actor: -18.3863, Critic: 4.5608
#   Causal Probs (S->R): ['0.50', '0.83', '0.32', '0.64']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 74/500 | Avg Steps (last 100): 45.62 | Steps: 206 | Time: 76.27s
# Reward: 206.0
#   Losses -> Gen: 417.1804 (Rew: 417.1538, Dyn: 0.0238, Reg: 0.0027)
#   Policy -> Actor: -20.5826, Critic: 5.8933
#   Causal Probs (S->R): ['0.50', '0.84', '0.34', '0.66']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 75/500 | Avg Steps (last 100): 46.84 | Steps: 137 | Time: 79.48s
# Reward: 137.0
#   Losses -> Gen: 600.4453 (Rew: 600.4249, Dyn: 0.0177, Reg: 0.0028)
#   Policy -> Actor: -20.9426, Critic: 2.6067
#   Causal Probs (S->R): ['0.51', '0.84', '0.34', '0.67']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 76/500 | Avg Steps (last 100): 49.20 | Steps: 226 | Time: 84.80s
# Reward: 226.0
#   Losses -> Gen: 16.3890 (Rew: 16.3817, Dyn: 0.0045, Reg: 0.0028)
#   Policy -> Actor: -23.4646, Critic: 2.4278
#   Causal Probs (S->R): ['0.52', '0.84', '0.36', '0.68']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 77/500 | Avg Steps (last 100): 50.69 | Steps: 164 | Time: 88.65s
# Reward: 164.0
#   Losses -> Gen: 114.8773 (Rew: 114.8598, Dyn: 0.0146, Reg: 0.0029)
#   Policy -> Actor: -24.4247, Critic: 1.1833
#   Causal Probs (S->R): ['0.51', '0.84', '0.36', '0.69']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 78/500 | Avg Steps (last 100): 51.99 | Steps: 152 | Time: 92.25s
# Reward: 152.0
#   Losses -> Gen: 105.2918 (Rew: 105.2780, Dyn: 0.0109, Reg: 0.0029)
#   Policy -> Actor: -24.5849, Critic: 4.1128
#   Causal Probs (S->R): ['0.52', '0.85', '0.37', '0.70']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 79/500 | Avg Steps (last 100): 53.48 | Steps: 170 | Time: 96.29s
# Reward: 170.0
#   Losses -> Gen: 87.4120 (Rew: 87.4064, Dyn: 0.0027, Reg: 0.0030)
#   Policy -> Actor: -27.6220, Critic: 1.7055
#   Causal Probs (S->R): ['0.52', '0.85', '0.38', '0.71']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 80/500 | Avg Steps (last 100): 54.62 | Steps: 145 | Time: 99.75s
# Reward: 145.0
#   Losses -> Gen: 212.7744 (Rew: 212.7511, Dyn: 0.0203, Reg: 0.0030)
#   Policy -> Actor: -28.2914, Critic: 10.9033
#   Causal Probs (S->R): ['0.52', '0.86', '0.39', '0.72']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 81/500 | Avg Steps (last 100): 55.78 | Steps: 148 | Time: 103.33s
# Reward: 148.0
#   Losses -> Gen: 272.5821 (Rew: 272.5660, Dyn: 0.0130, Reg: 0.0030)
#   Policy -> Actor: -28.3573, Critic: 1.8864
#   Causal Probs (S->R): ['0.52', '0.86', '0.39', '0.73']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 82/500 | Avg Steps (last 100): 57.17 | Steps: 170 | Time: 107.34s
# Reward: 170.0
#   Losses -> Gen: 40.7907 (Rew: 40.7841, Dyn: 0.0035, Reg: 0.0031)
#   Policy -> Actor: -30.3765, Critic: 1.5564
#   Causal Probs (S->R): ['0.52', '0.86', '0.40', '0.73']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 83/500 | Avg Steps (last 100): 58.11 | Steps: 135 | Time: 110.56s
# Reward: 135.0
#   Losses -> Gen: 31.6127 (Rew: 31.6007, Dyn: 0.0089, Reg: 0.0031)
#   Policy -> Actor: -32.3595, Critic: 18.8885
#   Causal Probs (S->R): ['0.52', '0.87', '0.41', '0.74']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 84/500 | Avg Steps (last 100): 60.57 | Steps: 265 | Time: 116.81s
# Reward: 265.0
#   Losses -> Gen: 115.2056 (Rew: 115.1903, Dyn: 0.0122, Reg: 0.0032)
#   Policy -> Actor: -33.5187, Critic: 0.8681
#   Causal Probs (S->R): ['0.52', '0.87', '0.42', '0.75']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 85/500 | Avg Steps (last 100): 61.74 | Steps: 160 | Time: 120.59s
# Reward: 160.0
#   Losses -> Gen: 16.7977 (Rew: 16.7867, Dyn: 0.0077, Reg: 0.0032)
#   Policy -> Actor: -34.1616, Critic: 4.4038
#   Causal Probs (S->R): ['0.53', '0.87', '0.43', '0.76']
#   Compact Mask: [0. 0. 0. 1.]
# Epi 86/500 | Avg Steps (last 100): 62.64 | Steps: 139 | Time: 123.90s
# Reward: 139.0
#   Losses -> Gen: 71.1434 (Rew: 71.1370, Dyn: 0.0031, Reg: 0.0033)
#   Policy -> Actor: -35.0513, Critic: 35.1909
#   Causal Probs (S->R): ['0.53', '0.87', '0.44', '0.76']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 87/500 | Avg Steps (last 100): 63.63 | Steps: 149 | Time: 127.40s
# Reward: 149.0
#   Losses -> Gen: 17.5612 (Rew: 17.5362, Dyn: 0.0217, Reg: 0.0033)
#   Policy -> Actor: -35.0949, Critic: 10.9743
#   Causal Probs (S->R): ['0.53', '0.88', '0.45', '0.77']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 88/500 | Avg Steps (last 100): 64.56 | Steps: 145 | Time: 130.87s
# Reward: 145.0
#   Losses -> Gen: 34.1494 (Rew: 34.1383, Dyn: 0.0078, Reg: 0.0033)
#   Policy -> Actor: -37.6438, Critic: 3.3463
#   Causal Probs (S->R): ['0.53', '0.88', '0.45', '0.78']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 89/500 | Avg Steps (last 100): 65.35 | Steps: 135 | Time: 134.07s
# Reward: 135.0
#   Losses -> Gen: 36.5815 (Rew: 36.5680, Dyn: 0.0102, Reg: 0.0034)
#   Policy -> Actor: -38.3126, Critic: 2.0242
#   Causal Probs (S->R): ['0.53', '0.88', '0.46', '0.78']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 90/500 | Avg Steps (last 100): 66.13 | Steps: 136 | Time: 137.29s
# Reward: 136.0
#   Losses -> Gen: 28.3562 (Rew: 28.3488, Dyn: 0.0040, Reg: 0.0034)
#   Policy -> Actor: -45.6475, Critic: 72.0738
#   Causal Probs (S->R): ['0.53', '0.88', '0.47', '0.78']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 91/500 | Avg Steps (last 100): 67.37 | Steps: 179 | Time: 141.50s
# Reward: 179.0
#   Losses -> Gen: 902.5182 (Rew: 902.5106, Dyn: 0.0042, Reg: 0.0034)
#   Policy -> Actor: -40.5520, Critic: 18.7596
#   Causal Probs (S->R): ['0.53', '0.89', '0.48', '0.79']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 92/500 | Avg Steps (last 100): 68.48 | Steps: 169 | Time: 145.48s
# Reward: 169.0
#   Losses -> Gen: 46.4883 (Rew: 46.4756, Dyn: 0.0092, Reg: 0.0035)
#   Policy -> Actor: -43.3761, Critic: 29.2421
#   Causal Probs (S->R): ['0.54', '0.89', '0.49', '0.80']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 93/500 | Avg Steps (last 100): 69.52 | Steps: 165 | Time: 149.38s
# Reward: 165.0
#   Losses -> Gen: 70.2744 (Rew: 70.2479, Dyn: 0.0230, Reg: 0.0035)
#   Policy -> Actor: -43.1955, Critic: 3.8958
#   Causal Probs (S->R): ['0.54', '0.89', '0.50', '0.80']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 94/500 | Avg Steps (last 100): 70.18 | Steps: 132 | Time: 152.51s
# Reward: 132.0
#   Losses -> Gen: 204.9390 (Rew: 204.9304, Dyn: 0.0051, Reg: 0.0035)
#   Policy -> Actor: -43.3592, Critic: 4.9981
#   Causal Probs (S->R): ['0.54', '0.89', '0.51', '0.80']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 95/500 | Avg Steps (last 100): 70.89 | Steps: 138 | Time: 155.77s
# Reward: 138.0
#   Losses -> Gen: 176.7553 (Rew: 176.7471, Dyn: 0.0046, Reg: 0.0036)
#   Policy -> Actor: -43.2176, Critic: 20.5608
#   Causal Probs (S->R): ['0.54', '0.89', '0.52', '0.81']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 96/500 | Avg Steps (last 100): 71.72 | Steps: 150 | Time: 159.29s
# Reward: 150.0
#   Losses -> Gen: 38.4710 (Rew: 38.4615, Dyn: 0.0059, Reg: 0.0036)
#   Policy -> Actor: -45.2196, Critic: 4.2969
#   Causal Probs (S->R): ['0.55', '0.90', '0.52', '0.81']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 97/500 | Avg Steps (last 100): 72.61 | Steps: 158 | Time: 162.99s
# Reward: 158.0
#   Losses -> Gen: 102.1480 (Rew: 102.1379, Dyn: 0.0065, Reg: 0.0036)
#   Policy -> Actor: -46.1091, Critic: 7.3964
#   Causal Probs (S->R): ['0.55', '0.90', '0.53', '0.81']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 98/500 | Avg Steps (last 100): 73.47 | Steps: 157 | Time: 166.66s
# Reward: 157.0
#   Losses -> Gen: 5.9508 (Rew: 5.9419, Dyn: 0.0052, Reg: 0.0037)
#   Policy -> Actor: -47.3654, Critic: 1.9436
#   Causal Probs (S->R): ['0.55', '0.90', '0.54', '0.82']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 99/500 | Avg Steps (last 100): 74.47 | Steps: 173 | Time: 170.75s
# Reward: 173.0
#   Losses -> Gen: 32.2078 (Rew: 32.1980, Dyn: 0.0062, Reg: 0.0037)
#   Policy -> Actor: -48.7685, Critic: 3.6640
#   Causal Probs (S->R): ['0.55', '0.90', '0.55', '0.82']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 100/500 | Avg Steps (last 100): 75.11 | Steps: 138 | Time: 174.01s
# Reward: 138.0
#   Losses -> Gen: 47.3055 (Rew: 47.2889, Dyn: 0.0128, Reg: 0.0038)
#   Policy -> Actor: -48.8028, Critic: 20.1432
#   Causal Probs (S->R): ['0.56', '0.90', '0.56', '0.82']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 101/500 | Avg Steps (last 100): 76.54 | Steps: 162 | Time: 177.84s
# Reward: 162.0
#   Losses -> Gen: 69.7372 (Rew: 69.6854, Dyn: 0.0481, Reg: 0.0038)
#   Policy -> Actor: -48.9020, Critic: 6.1877
#   Causal Probs (S->R): ['0.56', '0.90', '0.57', '0.83']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 102/500 | Avg Steps (last 100): 77.75 | Steps: 150 | Time: 181.35s
# Reward: 150.0
#   Losses -> Gen: 86.9320 (Rew: 86.9252, Dyn: 0.0030, Reg: 0.0038)
#   Policy -> Actor: -53.2477, Critic: 26.9520
#   Causal Probs (S->R): ['0.56', '0.90', '0.57', '0.83']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 103/500 | Avg Steps (last 100): 79.19 | Steps: 191 | Time: 185.84s
# Reward: 191.0
#   Losses -> Gen: 23.5438 (Rew: 23.5275, Dyn: 0.0124, Reg: 0.0039)
#   Policy -> Actor: -51.6870, Critic: 7.0762
#   Causal Probs (S->R): ['0.57', '0.91', '0.58', '0.83']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 104/500 | Avg Steps (last 100): 81.67 | Steps: 261 | Time: 191.97s
# Reward: 261.0
#   Losses -> Gen: 619.0615 (Rew: 619.0399, Dyn: 0.0178, Reg: 0.0039)
#   Policy -> Actor: -52.7116, Critic: 7.0843
#   Causal Probs (S->R): ['0.57', '0.91', '0.60', '0.84']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 105/500 | Avg Steps (last 100): 82.75 | Steps: 155 | Time: 195.59s
# Reward: 155.0
#   Losses -> Gen: 110.5109 (Rew: 110.4957, Dyn: 0.0112, Reg: 0.0040)
#   Policy -> Actor: -53.8548, Critic: 12.7077
#   Causal Probs (S->R): ['0.57', '0.91', '0.61', '0.84']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 106/500 | Avg Steps (last 100): 84.11 | Steps: 145 | Time: 198.98s
# Reward: 145.0
#   Losses -> Gen: 68.8673 (Rew: 68.8435, Dyn: 0.0197, Reg: 0.0040)
#   Policy -> Actor: -54.6900, Critic: 1.8080
#   Causal Probs (S->R): ['0.58', '0.91', '0.62', '0.84']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 107/500 | Avg Steps (last 100): 85.35 | Steps: 147 | Time: 202.47s
# Reward: 147.0
#   Losses -> Gen: 55.5211 (Rew: 55.5137, Dyn: 0.0033, Reg: 0.0040)
#   Policy -> Actor: -55.2931, Critic: 7.0529
#   Causal Probs (S->R): ['0.58', '0.91', '0.63', '0.85']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 108/500 | Avg Steps (last 100): 87.73 | Steps: 251 | Time: 208.36s
# Reward: 251.0
#   Losses -> Gen: 46.7521 (Rew: 46.7414, Dyn: 0.0067, Reg: 0.0041)
#   Policy -> Actor: -56.5839, Critic: 3.2732
#   Causal Probs (S->R): ['0.58', '0.91', '0.64', '0.85']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 109/500 | Avg Steps (last 100): 89.05 | Steps: 150 | Time: 211.90s
# Reward: 150.0
#   Losses -> Gen: 172.2946 (Rew: 172.2870, Dyn: 0.0036, Reg: 0.0041)
#   Policy -> Actor: -56.0476, Critic: 1.8104
#   Causal Probs (S->R): ['0.59', '0.92', '0.64', '0.85']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 110/500 | Avg Steps (last 100): 90.54 | Steps: 161 | Time: 215.68s
# Reward: 161.0
#   Losses -> Gen: 100.3965 (Rew: 100.3778, Dyn: 0.0146, Reg: 0.0042)
#   Policy -> Actor: -58.2041, Critic: 5.5146
#   Causal Probs (S->R): ['0.59', '0.92', '0.65', '0.85']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 111/500 | Avg Steps (last 100): 91.32 | Steps: 138 | Time: 218.93s
# Reward: 138.0
#   Losses -> Gen: 153.1644 (Rew: 153.1554, Dyn: 0.0049, Reg: 0.0042)
#   Policy -> Actor: -58.8334, Critic: 11.5322
#   Causal Probs (S->R): ['0.59', '0.92', '0.66', '0.86']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 112/500 | Avg Steps (last 100): 92.97 | Steps: 174 | Time: 223.00s
# Reward: 174.0
#   Losses -> Gen: 186.7794 (Rew: 186.7586, Dyn: 0.0165, Reg: 0.0042)
#   Policy -> Actor: -61.0043, Critic: 1.3653
#   Causal Probs (S->R): ['0.59', '0.92', '0.67', '0.86']
#   Compact Mask: [1. 1. 0. 1.]
# Epi 113/500 | Avg Steps (last 100): 95.33 | Steps: 245 | Time: 228.78s
# Reward: 245.0
#   Losses -> Gen: 73.1015 (Rew: 73.0936, Dyn: 0.0035, Reg: 0.0043)
#   Policy -> Actor: -74.7284, Critic: 38.7317
#   Causal Probs (S->R): ['0.60', '0.92', '0.68', '0.87']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 114/500 | Avg Steps (last 100): 96.51 | Steps: 146 | Time: 232.26s
# Reward: 146.0
#   Losses -> Gen: 15.8857 (Rew: 15.8765, Dyn: 0.0048, Reg: 0.0043)
#   Policy -> Actor: -61.5908, Critic: 3.3335
#   Causal Probs (S->R): ['0.60', '0.92', '0.68', '0.87']
#   Compact Mask: [0. 1. 1. 1.]
# Epi 115/500 | Avg Steps (last 100): 97.96 | Steps: 156 | Time: 235.93s
# Reward: 156.0
#   Losses -> Gen: 76.2779 (Rew: 76.2707, Dyn: 0.0028, Reg: 0.0044)
#   Policy -> Actor: -63.2212, Critic: 8.9042
#   Causal Probs (S->R): ['0.61', '0.92', '0.69', '0.87']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 116/500 | Avg Steps (last 100): 101.31 | Steps: 343 | Time: 244.00s
# Reward: 343.0
#   Losses -> Gen: 23.3244 (Rew: 23.3113, Dyn: 0.0086, Reg: 0.0045)
#   Policy -> Actor: -62.5120, Critic: 3.3659
#   Causal Probs (S->R): ['0.61', '0.93', '0.70', '0.88']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 117/500 | Avg Steps (last 100): 103.02 | Steps: 185 | Time: 248.35s
# Reward: 185.0
#   Losses -> Gen: 53.0744 (Rew: 53.0678, Dyn: 0.0021, Reg: 0.0045)
#   Policy -> Actor: -64.7278, Critic: 5.6667
#   Causal Probs (S->R): ['0.62', '0.93', '0.71', '0.88']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 118/500 | Avg Steps (last 100): 104.50 | Steps: 162 | Time: 252.18s
# Reward: 162.0
#   Losses -> Gen: 282.1452 (Rew: 282.1385, Dyn: 0.0021, Reg: 0.0046)
#   Policy -> Actor: -64.6815, Critic: 5.3769
#   Causal Probs (S->R): ['0.62', '0.93', '0.72', '0.88']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 119/500 | Avg Steps (last 100): 106.87 | Steps: 250 | Time: 258.59s
# Reward: 250.0
#   Losses -> Gen: 133.2424 (Rew: 133.2358, Dyn: 0.0020, Reg: 0.0046)
#   Policy -> Actor: -66.4522, Critic: 5.8101
#   Causal Probs (S->R): ['0.63', '0.93', '0.73', '0.88']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 120/500 | Avg Steps (last 100): 108.66 | Steps: 196 | Time: 263.53s
# Reward: 196.0
#   Losses -> Gen: 44.2359 (Rew: 44.2270, Dyn: 0.0043, Reg: 0.0047)
#   Policy -> Actor: -66.8574, Critic: 18.2387
#   Causal Probs (S->R): ['0.63', '0.94', '0.74', '0.89']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 121/500 | Avg Steps (last 100): 111.46 | Steps: 292 | Time: 270.79s
# Reward: 292.0
#   Losses -> Gen: 57.3265 (Rew: 57.3177, Dyn: 0.0040, Reg: 0.0048)
#   Policy -> Actor: -67.6663, Critic: 17.7823
#   Causal Probs (S->R): ['0.64', '0.94', '0.75', '0.89']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 122/500 | Avg Steps (last 100): 114.33 | Steps: 298 | Time: 278.36s
# Reward: 298.0
#   Losses -> Gen: 25.6542 (Rew: 25.6420, Dyn: 0.0073, Reg: 0.0048)
#   Policy -> Actor: -70.8954, Critic: 9.1009
#   Causal Probs (S->R): ['0.65', '0.94', '0.76', '0.89']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 123/500 | Avg Steps (last 100): 116.09 | Steps: 191 | Time: 283.13s
# Reward: 191.0
#   Losses -> Gen: 13.4119 (Rew: 13.3957, Dyn: 0.0113, Reg: 0.0049)
#   Policy -> Actor: -71.5208, Critic: 2.9559
#   Causal Probs (S->R): ['0.65', '0.94', '0.76', '0.90']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 124/500 | Avg Steps (last 100): 120.41 | Steps: 467 | Time: 294.60s
# Reward: 467.0
#   Losses -> Gen: 114.4494 (Rew: 114.4422, Dyn: 0.0021, Reg: 0.0050)
#   Policy -> Actor: -78.2689, Critic: 6.2005
#   Causal Probs (S->R): ['0.66', '0.95', '0.78', '0.90']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 125/500 | Avg Steps (last 100): 121.81 | Steps: 155 | Time: 298.41s
# Reward: 155.0
#   Losses -> Gen: 61.5449 (Rew: 61.5357, Dyn: 0.0041, Reg: 0.0051)
#   Policy -> Actor: -76.4899, Critic: 19.5226
#   Causal Probs (S->R): ['0.67', '0.95', '0.78', '0.90']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 126/500 | Avg Steps (last 100): 124.10 | Steps: 256 | Time: 304.68s
# Reward: 256.0
#   Losses -> Gen: 84.2239 (Rew: 84.2102, Dyn: 0.0086, Reg: 0.0051)
#   Policy -> Actor: -78.6325, Critic: 12.9253
#   Causal Probs (S->R): ['0.67', '0.95', '0.79', '0.91']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 127/500 | Avg Steps (last 100): 125.80 | Steps: 188 | Time: 309.33s
# Reward: 188.0
#   Losses -> Gen: 180.9346 (Rew: 180.9268, Dyn: 0.0026, Reg: 0.0052)
#   Policy -> Actor: -77.6100, Critic: 13.0423
#   Causal Probs (S->R): ['0.68', '0.95', '0.80', '0.91']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 128/500 | Avg Steps (last 100): 128.05 | Steps: 244 | Time: 315.37s
# Reward: 244.0
#   Losses -> Gen: 65.8267 (Rew: 65.8128, Dyn: 0.0087, Reg: 0.0053)
#   Policy -> Actor: -76.2433, Critic: 4.2194
#   Causal Probs (S->R): ['0.69', '0.95', '0.80', '0.91']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 129/500 | Avg Steps (last 100): 131.19 | Steps: 329 | Time: 323.44s
# Reward: 329.0
#   Losses -> Gen: 102.2627 (Rew: 102.2458, Dyn: 0.0115, Reg: 0.0054)
#   Policy -> Actor: -82.5332, Critic: 14.8602
#   Causal Probs (S->R): ['0.70', '0.96', '0.81', '0.91']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 130/500 | Avg Steps (last 100): 133.78 | Steps: 304 | Time: 330.91s
# Reward: 304.0
#   Losses -> Gen: 253.9732 (Rew: 253.9656, Dyn: 0.0022, Reg: 0.0054)
#   Policy -> Actor: -81.9730, Critic: 3.5333
#   Causal Probs (S->R): ['0.70', '0.96', '0.82', '0.91']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 131/500 | Avg Steps (last 100): 136.33 | Steps: 279 | Time: 337.74s
# Reward: 279.0
#   Losses -> Gen: 34.5234 (Rew: 34.5093, Dyn: 0.0086, Reg: 0.0055)
#   Policy -> Actor: -85.4733, Critic: 4.2574
#   Causal Probs (S->R): ['0.71', '0.96', '0.82', '0.91']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 132/500 | Avg Steps (last 100): 138.67 | Steps: 251 | Time: 344.39s
# Reward: 251.0
#   Losses -> Gen: 70.2966 (Rew: 70.2894, Dyn: 0.0017, Reg: 0.0055)
#   Policy -> Actor: -86.8590, Critic: 16.0821
#   Causal Probs (S->R): ['0.71', '0.96', '0.83', '0.92']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 133/500 | Avg Steps (last 100): 140.95 | Steps: 247 | Time: 350.52s
# Reward: 247.0
#   Losses -> Gen: 47.7542 (Rew: 47.7454, Dyn: 0.0032, Reg: 0.0056)
#   Policy -> Actor: -87.7660, Critic: 2.6025
#   Causal Probs (S->R): ['0.72', '0.96', '0.84', '0.92']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 134/500 | Avg Steps (last 100): 144.11 | Steps: 337 | Time: 358.98s
# Reward: 337.0
#   Losses -> Gen: 47.5747 (Rew: 47.5626, Dyn: 0.0063, Reg: 0.0057)
#   Policy -> Actor: -92.0067, Critic: 4.4527
#   Causal Probs (S->R): ['0.73', '0.96', '0.84', '0.92']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 135/500 | Avg Steps (last 100): 146.74 | Steps: 275 | Time: 365.74s
# Reward: 275.0
#   Losses -> Gen: 286.8617 (Rew: 286.8537, Dyn: 0.0023, Reg: 0.0058)
#   Policy -> Actor: -89.7790, Critic: 4.9367
#   Causal Probs (S->R): ['0.73', '0.96', '0.85', '0.92']
#   Compact Mask: [1. 0. 1. 1.]
# Epi 136/500 | Avg Steps (last 100): 148.63 | Steps: 232 | Time: 371.72s
# Reward: 232.0
#   Losses -> Gen: 45.5139 (Rew: 45.5003, Dyn: 0.0078, Reg: 0.0058)
#   Policy -> Actor: -92.0105, Critic: 2.8731
#   Causal Probs (S->R): ['0.73', '0.96', '0.85', '0.93']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 137/500 | Avg Steps (last 100): 150.24 | Steps: 179 | Time: 376.84s
# Reward: 179.0
#   Losses -> Gen: 99.8431 (Rew: 99.8331, Dyn: 0.0042, Reg: 0.0058)
#   Policy -> Actor: -91.9419, Critic: 4.1104
#   Causal Probs (S->R): ['0.74', '0.96', '0.86', '0.93']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 138/500 | Avg Steps (last 100): 154.65 | Steps: 460 | Time: 388.14s
# Reward: 460.0
#   Losses -> Gen: 91.1133 (Rew: 91.0886, Dyn: 0.0188, Reg: 0.0060)
#   Policy -> Actor: -92.8118, Critic: 39.5578
#   Causal Probs (S->R): ['0.75', '0.97', '0.87', '0.93']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 139/500 | Avg Steps (last 100): 157.13 | Steps: 265 | Time: 394.64s
# Reward: 265.0
#   Losses -> Gen: 498.2552 (Rew: 498.2437, Dyn: 0.0054, Reg: 0.0060)
#   Policy -> Actor: -97.2162, Critic: 8.1650
#   Causal Probs (S->R): ['0.75', '0.97', '0.87', '0.93']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 140/500 | Avg Steps (last 100): 160.30 | Steps: 335 | Time: 402.86s
# Reward: 335.0
#   Losses -> Gen: 50.4732 (Rew: 50.4547, Dyn: 0.0124, Reg: 0.0061)
#   Policy -> Actor: -98.5852, Critic: 12.1542
#   Causal Probs (S->R): ['0.75', '0.97', '0.88', '0.94']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 141/500 | Avg Steps (last 100): 162.73 | Steps: 262 | Time: 409.33s
# Reward: 262.0
#   Losses -> Gen: 1509.0547 (Rew: 1509.0410, Dyn: 0.0075, Reg: 0.0062)
#   Policy -> Actor: -97.9087, Critic: 6.9275
#   Causal Probs (S->R): ['0.76', '0.97', '0.88', '0.94']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 142/500 | Avg Steps (last 100): 165.53 | Steps: 306 | Time: 416.85s
# Reward: 306.0
#   Losses -> Gen: 44.3167 (Rew: 44.3065, Dyn: 0.0040, Reg: 0.0062)
#   Policy -> Actor: -100.2452, Critic: 19.8789
#   Causal Probs (S->R): ['0.76', '0.97', '0.89', '0.94']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 143/500 | Avg Steps (last 100): 168.17 | Steps: 277 | Time: 423.64s
# Reward: 277.0
#   Losses -> Gen: 170.0813 (Rew: 170.0727, Dyn: 0.0024, Reg: 0.0063)
#   Policy -> Actor: -101.7851, Critic: 5.0359
#   Causal Probs (S->R): ['0.76', '0.97', '0.89', '0.94']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 144/500 | Avg Steps (last 100): 170.38 | Steps: 239 | Time: 429.49s
# Reward: 239.0
#   Losses -> Gen: 261.6924 (Rew: 261.6824, Dyn: 0.0037, Reg: 0.0063)
#   Policy -> Actor: -106.1476, Critic: 15.2199
#   Causal Probs (S->R): ['0.77', '0.97', '0.89', '0.94']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 145/500 | Avg Steps (last 100): 172.92 | Steps: 273 | Time: 436.19s
# Reward: 273.0
#   Losses -> Gen: 71.2324 (Rew: 71.2101, Dyn: 0.0159, Reg: 0.0064)
#   Policy -> Actor: -104.4930, Critic: 40.0290
#   Causal Probs (S->R): ['0.77', '0.97', '0.90', '0.94']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 146/500 | Avg Steps (last 100): 174.57 | Steps: 184 | Time: 440.68s
# Reward: 184.0
#   Losses -> Gen: 651.9268 (Rew: 651.9189, Dyn: 0.0015, Reg: 0.0064)
#   Policy -> Actor: -103.8586, Critic: 13.7418
#   Causal Probs (S->R): ['0.77', '0.97', '0.90', '0.94']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 147/500 | Avg Steps (last 100): 176.82 | Steps: 239 | Time: 446.50s
# Reward: 239.0
#   Losses -> Gen: 98.2496 (Rew: 98.2386, Dyn: 0.0046, Reg: 0.0065)
#   Policy -> Actor: -101.3146, Critic: 68.1367
#   Causal Probs (S->R): ['0.77', '0.97', '0.90', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 148/500 | Avg Steps (last 100): 179.81 | Steps: 317 | Time: 454.26s
# Reward: 317.0
#   Losses -> Gen: 488.5445 (Rew: 488.5304, Dyn: 0.0076, Reg: 0.0065)
#   Policy -> Actor: -111.2779, Critic: 7.3941
#   Causal Probs (S->R): ['0.78', '0.97', '0.90', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 149/500 | Avg Steps (last 100): 181.62 | Steps: 211 | Time: 459.49s
# Reward: 211.0
#   Losses -> Gen: 841.2665 (Rew: 841.2524, Dyn: 0.0074, Reg: 0.0066)
#   Policy -> Actor: -111.6077, Critic: 8.0110
#   Causal Probs (S->R): ['0.78', '0.97', '0.91', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 150/500 | Avg Steps (last 100): 183.84 | Steps: 238 | Time: 466.23s
# Reward: 238.0
#   Losses -> Gen: 40.0125 (Rew: 40.0051, Dyn: 0.0008, Reg: 0.0066)
#   Policy -> Actor: -109.6596, Critic: 2.9586
#   Causal Probs (S->R): ['0.78', '0.97', '0.91', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 151/500 | Avg Steps (last 100): 185.44 | Steps: 190 | Time: 471.03s
# Reward: 190.0
#   Losses -> Gen: 28.0265 (Rew: 28.0185, Dyn: 0.0013, Reg: 0.0067)
#   Policy -> Actor: -112.8682, Critic: 9.2187
#   Causal Probs (S->R): ['0.78', '0.97', '0.91', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 152/500 | Avg Steps (last 100): 187.32 | Steps: 222 | Time: 476.52s
# Reward: 222.0
#   Losses -> Gen: 1.9235 (Rew: 1.9095, Dyn: 0.0074, Reg: 0.0067)
#   Policy -> Actor: -108.5985, Critic: 6.7690
#   Causal Probs (S->R): ['0.79', '0.97', '0.92', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 153/500 | Avg Steps (last 100): 189.21 | Steps: 212 | Time: 481.77s
# Reward: 212.0
#   Losses -> Gen: 33.6532 (Rew: 33.6301, Dyn: 0.0163, Reg: 0.0068)
#   Policy -> Actor: -112.0326, Critic: 98.4958
#   Causal Probs (S->R): ['0.79', '0.98', '0.92', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 154/500 | Avg Steps (last 100): 191.22 | Steps: 222 | Time: 487.28s
# Reward: 222.0
#   Losses -> Gen: 243.7373 (Rew: 243.7254, Dyn: 0.0051, Reg: 0.0068)
#   Policy -> Actor: -111.8598, Critic: 86.1744
#   Causal Probs (S->R): ['0.79', '0.98', '0.92', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 155/500 | Avg Steps (last 100): 193.99 | Steps: 293 | Time: 494.50s
# Reward: 293.0
#   Losses -> Gen: 732.1315 (Rew: 732.1208, Dyn: 0.0038, Reg: 0.0069)
#   Policy -> Actor: -115.2227, Critic: 8.7040
#   Causal Probs (S->R): ['0.80', '0.98', '0.92', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 156/500 | Avg Steps (last 100): 195.77 | Steps: 246 | Time: 500.58s
# Reward: 246.0
#   Losses -> Gen: 65.9994 (Rew: 65.9866, Dyn: 0.0060, Reg: 0.0069)
#   Policy -> Actor: -117.9605, Critic: 10.4279
#   Causal Probs (S->R): ['0.80', '0.98', '0.93', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 157/500 | Avg Steps (last 100): 196.72 | Steps: 181 | Time: 505.02s
# Reward: 181.0
#   Losses -> Gen: 54.9122 (Rew: 54.9014, Dyn: 0.0038, Reg: 0.0069)
#   Policy -> Actor: -118.5374, Critic: 13.6405
#   Causal Probs (S->R): ['0.80', '0.98', '0.93', '0.95']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 158/500 | Avg Steps (last 100): 198.99 | Steps: 271 | Time: 511.66s
# Reward: 271.0
#   Losses -> Gen: 125.0388 (Rew: 125.0302, Dyn: 0.0016, Reg: 0.0070)
#   Policy -> Actor: -121.5767, Critic: 79.7617
#   Causal Probs (S->R): ['0.80', '0.98', '0.93', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 159/500 | Avg Steps (last 100): 200.52 | Steps: 244 | Time: 517.80s
# Reward: 244.0
#   Losses -> Gen: 130.6954 (Rew: 130.6839, Dyn: 0.0044, Reg: 0.0070)
#   Policy -> Actor: -119.6387, Critic: 10.1547
#   Causal Probs (S->R): ['0.80', '0.98', '0.93', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 160/500 | Avg Steps (last 100): 202.11 | Steps: 220 | Time: 523.20s
# Reward: 220.0
#   Losses -> Gen: 88.8141 (Rew: 88.8005, Dyn: 0.0066, Reg: 0.0071)
#   Policy -> Actor: -113.0626, Critic: 27.1961
#   Causal Probs (S->R): ['0.80', '0.98', '0.93', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 161/500 | Avg Steps (last 100): 203.37 | Steps: 201 | Time: 528.15s
# Reward: 201.0
#   Losses -> Gen: 76.9383 (Rew: 76.9299, Dyn: 0.0013, Reg: 0.0071)
#   Policy -> Actor: -123.7045, Critic: 13.1212
#   Causal Probs (S->R): ['0.80', '0.98', '0.94', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 162/500 | Avg Steps (last 100): 204.42 | Steps: 225 | Time: 533.73s
# Reward: 225.0
#   Losses -> Gen: 178.1409 (Rew: 178.1255, Dyn: 0.0083, Reg: 0.0071)
#   Policy -> Actor: -117.5991, Critic: 115.6856
#   Causal Probs (S->R): ['0.80', '0.98', '0.94', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 163/500 | Avg Steps (last 100): 206.09 | Steps: 236 | Time: 539.70s
# Reward: 236.0
#   Losses -> Gen: 126.3171 (Rew: 126.2835, Dyn: 0.0264, Reg: 0.0072)
#   Policy -> Actor: -123.2629, Critic: 114.5577
#   Causal Probs (S->R): ['0.81', '0.98', '0.94', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 164/500 | Avg Steps (last 100): 207.69 | Steps: 242 | Time: 545.66s
# Reward: 242.0
#   Losses -> Gen: 54.7882 (Rew: 54.7793, Dyn: 0.0018, Reg: 0.0072)
#   Policy -> Actor: -125.2252, Critic: 25.1693
#   Causal Probs (S->R): ['0.81', '0.98', '0.94', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 165/500 | Avg Steps (last 100): 209.53 | Steps: 296 | Time: 552.93s
# Reward: 296.0
#   Losses -> Gen: 110.1825 (Rew: 110.1727, Dyn: 0.0026, Reg: 0.0073)
#   Policy -> Actor: -130.2453, Critic: 139.1666
#   Causal Probs (S->R): ['0.81', '0.98', '0.94', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 166/500 | Avg Steps (last 100): 210.13 | Steps: 251 | Time: 559.08s
# Reward: 251.0
#   Losses -> Gen: 18.0895 (Rew: 18.0798, Dyn: 0.0024, Reg: 0.0073)
#   Policy -> Actor: -129.4830, Critic: 13.2324
#   Causal Probs (S->R): ['0.81', '0.98', '0.95', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 167/500 | Avg Steps (last 100): 210.93 | Steps: 194 | Time: 563.83s
# Reward: 194.0
#   Losses -> Gen: 111.8325 (Rew: 111.8227, Dyn: 0.0024, Reg: 0.0074)
#   Policy -> Actor: -127.3533, Critic: 7.7073
#   Causal Probs (S->R): ['0.81', '0.98', '0.95', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 168/500 | Avg Steps (last 100): 212.08 | Steps: 204 | Time: 568.85s
# Reward: 204.0
#   Losses -> Gen: 103.3103 (Rew: 103.3004, Dyn: 0.0026, Reg: 0.0074)
#   Policy -> Actor: -127.5038, Critic: 13.3942
#   Causal Probs (S->R): ['0.81', '0.98', '0.95', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 169/500 | Avg Steps (last 100): 212.96 | Steps: 199 | Time: 573.77s
# Reward: 199.0
#   Losses -> Gen: 1562.0985 (Rew: 1562.0653, Dyn: 0.0257, Reg: 0.0074)
#   Policy -> Actor: -130.8733, Critic: 20.5536
#   Causal Probs (S->R): ['0.81', '0.98', '0.95', '0.96']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 170/500 | Avg Steps (last 100): 213.38 | Steps: 214 | Time: 579.06s
# Reward: 214.0
#   Losses -> Gen: 179.5040 (Rew: 179.4939, Dyn: 0.0027, Reg: 0.0075)
#   Policy -> Actor: -126.9357, Critic: 13.2018
#   Causal Probs (S->R): ['0.82', '0.98', '0.95', '0.97']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 171/500 | Avg Steps (last 100): 214.30 | Steps: 264 | Time: 585.55s
# Reward: 264.0
#   Losses -> Gen: 101.4726 (Rew: 101.4631, Dyn: 0.0020, Reg: 0.0075)
#   Policy -> Actor: -132.0213, Critic: 7.7367
#   Causal Probs (S->R): ['0.82', '0.98', '0.95', '0.97']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 172/500 | Avg Steps (last 100): 214.31 | Steps: 214 | Time: 590.78s
# Reward: 214.0
#   Losses -> Gen: 61.1559 (Rew: 61.1463, Dyn: 0.0021, Reg: 0.0075)
#   Policy -> Actor: -128.7141, Critic: 11.9749
#   Causal Probs (S->R): ['0.82', '0.98', '0.95', '0.97']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 173/500 | Avg Steps (last 100): 215.04 | Steps: 224 | Time: 596.32s
# Reward: 224.0
#   Losses -> Gen: 93.5512 (Rew: 93.5423, Dyn: 0.0013, Reg: 0.0076)
#   Policy -> Actor: -124.3196, Critic: 11.2997
#   Causal Probs (S->R): ['0.82', '0.98', '0.95', '0.97']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 174/500 | Avg Steps (last 100): 216.07 | Steps: 309 | Time: 603.88s
# Reward: 309.0
#   Losses -> Gen: 44.5024 (Rew: 44.4911, Dyn: 0.0037, Reg: 0.0076)
#   Policy -> Actor: -134.0292, Critic: 118.2234
#   Causal Probs (S->R): ['0.82', '0.98', '0.96', '0.97']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 175/500 | Avg Steps (last 100): 217.09 | Steps: 239 | Time: 609.76s
# ...
# Reward: 500.0
#   Losses -> Gen: 124.7927 (Rew: 124.7752, Dyn: 0.0001, Reg: 0.0173)
#   Policy -> Actor: -428.1397, Critic: 2780.2319
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 446/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3774.35s
# Reward: 500.0
#   Losses -> Gen: 53.9646 (Rew: 53.9470, Dyn: 0.0003, Reg: 0.0174)
#   Policy -> Actor: -430.3304, Critic: 8.6234
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 447/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3786.85s
# Reward: 500.0
#   Losses -> Gen: 57.8454 (Rew: 57.8279, Dyn: 0.0001, Reg: 0.0174)
#   Policy -> Actor: -429.0447, Critic: 3.9945
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 448/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3799.30s
# Reward: 500.0
#   Losses -> Gen: 187.8212 (Rew: 187.8036, Dyn: 0.0002, Reg: 0.0174)
#   Policy -> Actor: -429.4602, Critic: 4.4180
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 449/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3811.87s
# Reward: 500.0
#   Losses -> Gen: 85.6369 (Rew: 85.6194, Dyn: 0.0001, Reg: 0.0174)
#   Policy -> Actor: -426.3253, Critic: 4186.7563
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 450/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3824.30s
# Reward: 500.0
#   Losses -> Gen: 111.7662 (Rew: 111.7487, Dyn: 0.0001, Reg: 0.0174)
#   Policy -> Actor: -425.5464, Critic: 2719.6272
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 451/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3836.71s
# Reward: 500.0
#   Losses -> Gen: 105.6335 (Rew: 105.6159, Dyn: 0.0002, Reg: 0.0174)
#   Policy -> Actor: -425.5212, Critic: 7.6125
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 452/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3849.24s
# Reward: 500.0
#   Losses -> Gen: 37.2770 (Rew: 37.2595, Dyn: 0.0001, Reg: 0.0175)
#   Policy -> Actor: -428.0823, Critic: 1371.9554
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 453/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3861.99s
# Reward: 500.0
#   Losses -> Gen: 407.3115 (Rew: 407.2939, Dyn: 0.0001, Reg: 0.0175)
#   Policy -> Actor: -426.1159, Critic: 8.0739
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 454/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3874.51s
# Reward: 500.0
#   Losses -> Gen: 228.0117 (Rew: 227.9939, Dyn: 0.0002, Reg: 0.0175)
#   Policy -> Actor: -426.1692, Critic: 3.8378
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 455/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3886.92s
# Reward: 500.0
#   Losses -> Gen: 69.7895 (Rew: 69.7715, Dyn: 0.0005, Reg: 0.0175)
#   Policy -> Actor: -424.2434, Critic: 1419.9312
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 456/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3899.36s
# Reward: 500.0
#   Losses -> Gen: 60.9655 (Rew: 60.9473, Dyn: 0.0006, Reg: 0.0175)
#   Policy -> Actor: -426.7015, Critic: 4.0297
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 457/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3911.76s
# Reward: 500.0
#   Losses -> Gen: 76.5008 (Rew: 76.4830, Dyn: 0.0002, Reg: 0.0175)
#   Policy -> Actor: -424.5815, Critic: 1386.3425
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 458/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3924.16s
# Reward: 500.0
#   Losses -> Gen: 128.9584 (Rew: 128.9407, Dyn: 0.0002, Reg: 0.0175)
#   Policy -> Actor: -425.8638, Critic: 1401.1409
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 459/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3936.56s
# Reward: 500.0
#   Losses -> Gen: 17.2160 (Rew: 17.1984, Dyn: 0.0001, Reg: 0.0176)
#   Policy -> Actor: -424.7541, Critic: 3.4654
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 460/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3949.05s
# Reward: 500.0
#   Losses -> Gen: 1116.8070 (Rew: 1116.7893, Dyn: 0.0002, Reg: 0.0176)
#   Policy -> Actor: -424.2783, Critic: 8.6591
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 461/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3961.58s
# Reward: 500.0
#   Losses -> Gen: 340.0425 (Rew: 340.0248, Dyn: 0.0001, Reg: 0.0176)
#   Policy -> Actor: -425.5347, Critic: 4.4778
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 462/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3974.25s
# Reward: 500.0
#   Losses -> Gen: 176.3061 (Rew: 176.2884, Dyn: 0.0001, Reg: 0.0176)
#   Policy -> Actor: -423.2276, Critic: 5.5787
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 463/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3986.79s
# Reward: 500.0
#   Losses -> Gen: 62.6360 (Rew: 62.6180, Dyn: 0.0004, Reg: 0.0176)
#   Policy -> Actor: -424.0870, Critic: 4.8558
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 464/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 3999.32s
# Reward: 500.0
#   Losses -> Gen: 161.8869 (Rew: 161.8690, Dyn: 0.0002, Reg: 0.0177)
#   Policy -> Actor: -423.9619, Critic: 4.2654
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 465/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4011.77s
# Reward: 500.0
#   Losses -> Gen: 69.9584 (Rew: 69.9405, Dyn: 0.0002, Reg: 0.0177)
#   Policy -> Actor: -420.5796, Critic: 11.6398
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 466/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4024.23s
# Reward: 500.0
#   Losses -> Gen: 104.7552 (Rew: 104.7373, Dyn: 0.0002, Reg: 0.0177)
#   Policy -> Actor: -422.5743, Critic: 1289.2745
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 467/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4036.59s
# Reward: 500.0
#   Losses -> Gen: 42.8730 (Rew: 42.8552, Dyn: 0.0001, Reg: 0.0177)
#   Policy -> Actor: -420.4889, Critic: 6.1077
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 468/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4048.99s
# Reward: 500.0
#   Losses -> Gen: 333.4377 (Rew: 333.4196, Dyn: 0.0002, Reg: 0.0177)
#   Policy -> Actor: -420.0022, Critic: 19.8520
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 469/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4061.44s
# Reward: 500.0
#   Losses -> Gen: 177.9473 (Rew: 177.9294, Dyn: 0.0002, Reg: 0.0178)
#   Policy -> Actor: -422.6039, Critic: 1355.9253
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 470/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4073.85s
# Reward: 500.0
#   Losses -> Gen: 201.4998 (Rew: 201.4820, Dyn: 0.0001, Reg: 0.0178)
#   Policy -> Actor: -419.1067, Critic: 2663.6414
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 471/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4086.34s
# Reward: 500.0
#   Losses -> Gen: 75.8470 (Rew: 75.8286, Dyn: 0.0006, Reg: 0.0178)
#   Policy -> Actor: -419.6729, Critic: 1327.7573
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 472/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4098.79s
# Reward: 500.0
#   Losses -> Gen: 56.7223 (Rew: 56.7043, Dyn: 0.0002, Reg: 0.0178)
#   Policy -> Actor: -419.5857, Critic: 3.2006
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 473/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4111.24s
# Reward: 500.0
#   Losses -> Gen: 161.0328 (Rew: 161.0147, Dyn: 0.0002, Reg: 0.0178)
#   Policy -> Actor: -419.0692, Critic: 12.8077
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 474/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4123.77s
# Reward: 500.0
#   Losses -> Gen: 530.2698 (Rew: 530.2512, Dyn: 0.0008, Reg: 0.0179)
#   Policy -> Actor: -416.8889, Critic: 1329.9426
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 475/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4136.21s
# Reward: 500.0
#   Losses -> Gen: 18.4378 (Rew: 18.4198, Dyn: 0.0001, Reg: 0.0179)
#   Policy -> Actor: -416.2296, Critic: 2650.1243
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 476/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4148.65s
# Reward: 500.0
#   Losses -> Gen: 358.4518 (Rew: 358.4333, Dyn: 0.0006, Reg: 0.0179)
#   Policy -> Actor: -417.7061, Critic: 2623.9771
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 477/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4161.11s
# Reward: 500.0
#   Losses -> Gen: 79.4749 (Rew: 79.4562, Dyn: 0.0008, Reg: 0.0179)
#   Policy -> Actor: -417.5955, Critic: 6.7948
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 478/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4173.79s
# Reward: 500.0
#   Losses -> Gen: 135.2113 (Rew: 135.1932, Dyn: 0.0001, Reg: 0.0179)
#   Policy -> Actor: -419.1351, Critic: 1337.4199
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 479/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4186.10s
# Reward: 500.0
#   Losses -> Gen: 177.8495 (Rew: 177.8314, Dyn: 0.0001, Reg: 0.0179)
#   Policy -> Actor: -419.3059, Critic: 3.2736
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 480/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4198.46s
# Reward: 500.0
#   Losses -> Gen: 24.0147 (Rew: 23.9966, Dyn: 0.0001, Reg: 0.0179)
#   Policy -> Actor: -417.8828, Critic: 8.7170
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 481/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4210.86s
# Reward: 500.0
#   Losses -> Gen: 34.7814 (Rew: 34.7633, Dyn: 0.0001, Reg: 0.0180)
#   Policy -> Actor: -418.4598, Critic: 10.1440
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 482/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4223.25s
# Reward: 500.0
#   Losses -> Gen: 46.3728 (Rew: 46.3547, Dyn: 0.0001, Reg: 0.0180)
#   Policy -> Actor: -418.8499, Critic: 2.6998
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 483/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4235.68s
# Reward: 500.0
#   Losses -> Gen: 79.7228 (Rew: 79.7045, Dyn: 0.0003, Reg: 0.0180)
#   Policy -> Actor: -417.1907, Critic: 17.6551
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 484/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4248.06s
# Reward: 500.0
#   Losses -> Gen: 69.9440 (Rew: 69.9258, Dyn: 0.0002, Reg: 0.0180)
#   Policy -> Actor: -423.3309, Critic: 1349.8469
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 485/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4260.46s
# Reward: 500.0
#   Losses -> Gen: 20.9929 (Rew: 20.9747, Dyn: 0.0002, Reg: 0.0180)
#   Policy -> Actor: -419.8658, Critic: 1642.6240
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 486/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4273.20s
# Reward: 500.0
#   Losses -> Gen: 109.1427 (Rew: 109.1244, Dyn: 0.0003, Reg: 0.0181)
#   Policy -> Actor: -421.0368, Critic: 7.5169
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 487/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4285.62s
# Reward: 500.0
#   Losses -> Gen: 39.6054 (Rew: 39.5872, Dyn: 0.0001, Reg: 0.0181)
#   Policy -> Actor: -417.8391, Critic: 9.9322
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 488/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4298.06s
# Reward: 500.0
#   Losses -> Gen: 34.3487 (Rew: 34.3304, Dyn: 0.0002, Reg: 0.0181)
#   Policy -> Actor: -418.8895, Critic: 4.2886
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 489/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4310.52s
# Reward: 500.0
#   Losses -> Gen: 252.9220 (Rew: 252.9038, Dyn: 0.0001, Reg: 0.0181)
#   Policy -> Actor: -418.4332, Critic: 2655.0776
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 490/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4323.01s
# Reward: 500.0
#   Losses -> Gen: 65.3570 (Rew: 65.3387, Dyn: 0.0001, Reg: 0.0181)
#   Policy -> Actor: -420.3060, Critic: 1373.9661
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 491/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4335.42s
# Reward: 500.0
#   Losses -> Gen: 114.9703 (Rew: 114.9521, Dyn: 0.0001, Reg: 0.0182)
#   Policy -> Actor: -420.2381, Critic: 5.8806
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 492/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4347.83s
# Reward: 500.0
#   Losses -> Gen: 131.2746 (Rew: 131.2562, Dyn: 0.0002, Reg: 0.0182)
#   Policy -> Actor: -419.7218, Critic: 5.4032
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 493/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4360.46s
# Reward: 500.0
#   Losses -> Gen: 80.4631 (Rew: 80.4445, Dyn: 0.0004, Reg: 0.0182)
#   Policy -> Actor: -418.1702, Critic: 5.0816
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 494/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4372.90s
# Reward: 500.0
#   Losses -> Gen: 255.3415 (Rew: 255.3231, Dyn: 0.0002, Reg: 0.0182)
#   Policy -> Actor: -418.0342, Critic: 1414.8179
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 495/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4385.28s
# Reward: 500.0
#   Losses -> Gen: 423.7289 (Rew: 423.7105, Dyn: 0.0002, Reg: 0.0182)
#   Policy -> Actor: -418.1551, Critic: 1331.8271
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 496/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4397.72s
# Reward: 500.0
#   Losses -> Gen: 75.5153 (Rew: 75.4969, Dyn: 0.0001, Reg: 0.0182)
#   Policy -> Actor: -420.4568, Critic: 3.7586
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 497/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4410.12s
# Reward: 500.0
#   Losses -> Gen: 52.7146 (Rew: 52.6961, Dyn: 0.0002, Reg: 0.0183)
#   Policy -> Actor: -417.8488, Critic: 1355.0029
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 498/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4422.56s
# Reward: 500.0
#   Losses -> Gen: 331.9955 (Rew: 331.9770, Dyn: 0.0002, Reg: 0.0183)
#   Policy -> Actor: -418.1759, Critic: 2.9812
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 499/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4434.98s
# Reward: 500.0
#   Losses -> Gen: 43.3019 (Rew: 43.2834, Dyn: 0.0002, Reg: 0.0183)
#   Policy -> Actor: -418.1481, Critic: 2611.1067
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]
# Epi 500/500 | Avg Steps (last 100): 500.00 | Steps: 500 | Time: 4447.38s
# Reward: 500.0
#   Losses -> Gen: 41.6542 (Rew: 41.6357, Dyn: 0.0001, Reg: 0.0183)
#   Policy -> Actor: -420.4604, Critic: 7.5705
#   Causal Probs (S->R): ['1.00', '1.00', '1.00', '1.00']
#   Compact Mask: [1. 1. 1. 1.]

# %%
sac_agent.save('weights')
generative_model.save('weights')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
nrewards = np.array(rewards, dtype=float)
nrewards = np.cumsum(nrewards)
plt.plot(range(len(nrewards)), nrewards)
plt.show()

with open('results/grd_rewards.pkl', 'wb') as f:
    pkl.dump(rewards, f)
